# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember']

#Pengeluaran antara 500.000 - 2.000.000

Minggu_1 = np.random.randint(500000,2000001,12)
Minggu_2 = np.random.randint(500000,2000001,12)
Minggu_3 = np.random.randint(500000,2000001,12)
Minggu_4 = np.random.randint(500000,2000001,12)

data = {
    'Bulan' : bulan,
    'Minggu_1' : Minggu_1,
    'Minggu_2' : Minggu_2,
    'Minggu_3' : Minggu_3,
    'Minggu_4' : Minggu_4
}

df = pd.DataFrame(data)

df['Total_Pengeluaran'] = df[['Minggu_1','Minggu_2','Minggu_3','Minggu_4']].sum(axis=1)
df
# Out:
#         Bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total_Pengeluaran
# 0     Januari   1899420   1369375   1293801   1717777            6280373
# 1    Februari   1993854    991252   1655895   1863190            6504191
# 2       Maret    771352    940301    623880   1515056            3850589
# 3       April   1719280   1452155   1968979   1223144            6363558
# 4         Mei   1081923   1549892    789092   1079235            4500142
# 5        Juni   1470498   1933359   1173806   1817428            6395091
# 6        Juli   1877145   1972472    975986   1012900            5838503
# 7     Agustus   1087272   1909411   1139111   1598744            5734538
# 8   September    939711    862828   1243168   1896099            4941806
# 9     Oktober    609111   1472377    658934   1592720            4333142
# 10   November   1329059    915024    860892   1888345            4993320
# 11   Desember   1318177   1863192   1033218   1126732            5341319

# %%
#Total Pengeluaran Per Bulan

plt.figure(figsize=(12,6))#Canvas dengan ukuran width, height (inch)
plt.title('Total Pengeluaran Per Bulan')
plt.bar(df['Bulan'],df['Total_Pengeluaran'],color='pink')
plt.xticks(rotation=45)
plt.ylabel("Rupiah")
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
#Scatter Plot untuk analisis data pengeluaran per minggu per bulan
plt.figure(figsize=(12,6))
for minggu in ['Minggu_1','Minggu_2','Minggu_3','Minggu_4']:
    plt.plot(df['Bulan'],df[minggu],marker='o',label=minggu)

plt.title("Pengeluaran Per Minggu")
plt.xlabel('Bulan')
plt.ylabel('Pengeluaran (Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie Chart -> Prosentase
plt.figure(figsize=(6,6))
plt.pie(df['Total_Pengeluaran'],labels=df['Bulan'],startangle=90,autopct='%1.1f%%')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1,13)

X = df[['Bulan_Angka']]
y = df['Total_Pengeluaran']

model = LinearRegression()

model.fit(X,y)

prediksi = model.predict([[13]])[0]
print(f"Hasil Prediksi adalah :{prediksi}")
# Out:
# Hasil Prediksi adalah :4865963.075757576
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('bapenda-od_19990_jml_kndrn__tipe_roda_kndrn_kabupatenkota_v5_data.csv')
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3201
# 2      3             32    JAWA BARAT                 3202
# 3      4             32    JAWA BARAT                 3202
# 4      5             32    JAWA BARAT                 3203
# ..   ...            ...           ...                  ...
# 373  374             32    JAWA BARAT                 3277
# 374  375             32    JAWA BARAT                 3278
# 375  376             32    JAWA BARAT                 3278
# 376  377             32    JAWA BARAT                 3279
# 377  378             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota tipe_roda_kendaraan  jumlah_kendaraan satuan  tahun
# 0       KABUPATEN BOGOR              RODA 2           1404250   UNIT   2018
# 1       KABUPATEN BOGOR              RODA 4            204207   UNIT   2018
# ...

# %% [markdown]
# <p>Sekenario Analisis Data</p>
# <ol>
#     <li>Wiayah yang diteliti adalah jawa barat</li>
#     <li>Jumlah Kendaraan roda 4 paling sedikit ada di kota Banjar dengan 56.970 unit </li>
#     <li>Jumlah Kendaraan roda 2 paling sedikit ada di kota Banjar dengan 421.399 unit </li>
#     <li>Jumlah Kendaraan roda 4 paling banyak ada di kota Bandung dengan 3.188.663 unit </li>
#     <li>Jumlah Kendaraan roda 2 paling sedikit ada di kabupaten Bogor dengan 10.118.397 unit </li>
#     <li>Jumlah Kendaraan roda 2 paling sedikit di tahun 2018 ada di kota Banjar dengan 62.997 unit </li>
#     <li>Jumlah Kendaraan roda 2 paling sedikit di tahun 2024 ada di kota Banjar dengan 58.452 unit </li>
# </ol>
